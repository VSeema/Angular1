# %% [markdown]
# <a href="https://colab.research.google.com/github/VSeema/Angular1/blob/master/cricket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install db-sqlite3

# %%
import pandas as pd
import sqlite3

# %%
db=sqlite3.connect("test")
db.execute("drop table if exists criket")
try:
  db.execute("create table criket(Pos Integer,Player text,Team text,Span text,Innings Integer,Runs Integer,HighestScore Integer,Average Double,StrikeRate Double)")
except:
  print("already table existed")

# %%
db=sqlite3.connect("test")

# %%
db.commit()

# %%
db=sqlite3.connect("test")
rs=db.execute("Select * from criket")
for row in rs:
  print(row)
# Out:
# (1, 'Sachin Tendulkar', 'India', '1989-2012', 452, 18426, 200, 44.83, 86.23)
# (2, 'Kumar Sangakkara', 'Sri Lanka', '2000-2015', 380, 14234, 169, 41.98, 78.86)
# (3, 'Ricky Ponting', 'Australia', '1995-2012', 365, 13704, 164, 42.03, 80.39)
# (4, 'Sanath Jayasuriya', 'Sri Lanka', '1989-2011', 433, 13430, 189, 32.36, 91.2)
# (5, 'Mahela Jayawardene', 'Sri Lanka', '1998-2015', 418, 12650, 144, 33.37, 78.96)
# (6, 'Virat Kohli', 'India', '2008-2020', 236, 11867, 183, 59.85, 93.39)
# (7, 'Inzamam-ul-Haq', 'Pakistan', '1991-2007', 350, 11739, 137, 39.52, 74.24)
# (8, 'Jacques Kallis', 'South Africa', '1996-2014', 314, 11579, 139, 44.36, 72.89)
# (9, 'Saurav Ganguly', 'India', '1992-2007', 300, 11363, 183, 41.02, 73.7)
# (10, 'Rahul Dravid', 'India', '1996-2011', 318, 10889, 153, 39.16, 71.24)

# %%
db=sqlite3.connect("test")
qry ="""
Select * from criket
"""
data=pd.read_sql_query(qry,db)
data
# Out:
#    Pos              Player          Team  ... HighestScore  Average  StrikeRate
# 0    1    Sachin Tendulkar         India  ...          200    44.83       86.23
# 1    2    Kumar Sangakkara     Sri Lanka  ...          169    41.98       78.86
# 2    3       Ricky Ponting     Australia  ...          164    42.03       80.39
# 3    4   Sanath Jayasuriya     Sri Lanka  ...          189    32.36       91.20
# 4    5  Mahela Jayawardene     Sri Lanka  ...          144    33.37       78.96
# 5    6         Virat Kohli         India  ...          183    59.85       93.39
# 6    7      Inzamam-ul-Haq      Pakistan  ...          137    39.52       74.24
# 7    8      Jacques Kallis  South Africa  ...          139    44.36       72.89
# 8    9      Saurav Ganguly         India  ...          183    41.02       73.70
# 9   10        Rahul Dravid         India  ...          153    39.16       71.24
#
# [10 rows x 9 columns]

# %%
! git clone https://github.com/google-research/tapas.git
# Out:
# Cloning into 'tapas'...
# remote: Enumerating objects: 442, done.
# remote: Total 442 (delta 0), reused 0 (delta 0), pack-reused 442
# Receiving objects: 100% (442/442), 298.94 KiB | 3.11 MiB/s, done.
# Resolving deltas: 100% (276/276), done.

# %%
! pip install ./tapas
# Out:
# Processing ./tapas
# ...
#      |████████████████████████████████| 3.5MB 6.4MB/s
# ...
#      |████████████████████████████████| 10.1MB 39.1MB/s
# ...
#      |████████████████████████████████| 516.2MB 32kB/s
# ...
#      |████████████████████████████████| 716kB 38.5MB/s
# ...
#      |████████████████████████████████| 61kB 6.0MB/s
# ...
#      |████████████████████████████████| 3.5MB 41.5MB/s
# ...
#      |████████████████████████████████| 358kB 43.5MB/s
# ...
#      |████████████████████████████████| 1.4MB 44.1MB/s
# ...
#      |████████████████████████████████| 61kB 7.4MB/s
# ...
#      |████████████████████████████████| 1.2MB 45.0MB/s
# ...
#      |████████████████████████████████| 63.2MB 71kB/s
# ...
#      |████████████████████████████████| 153kB 50.8MB/s
# ...
#      |████████████████████████████████| 225kB 44.9MB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#      |████████████████████████████████| 81kB 8.1MB/s
# ...
#      |████████████████████████████████| 235kB 39.3MB/s
# ...
#      |████████████████████████████████| 92kB 9.8MB/s
# ...

# %%
! gsutil cp gs://tapas_models/2020_04_21/tapas_sqa_base.zip . && unzip tapas_sqa_base.zip
# Out:
# Copying gs://tapas_models/2020_04_21/tapas_sqa_base.zip...
# - [1 files][  1.0 GiB/  1.0 GiB]   52.9 MiB/s
# Operation completed over 1 objects/1.0 GiB.
# Archive:  tapas_sqa_base.zip
#    creating: tapas_sqa_base/
#   inflating: tapas_sqa_base/model.ckpt.data-00000-of-00001
#   inflating: tapas_sqa_base/model.ckpt.index
#   inflating: tapas_sqa_base/README.txt
#   inflating: tapas_sqa_base/vocab.txt
#   inflating: tapas_sqa_base/bert_config.json
#   inflating: tapas_sqa_base/model.ckpt.meta

# %%
import tensorflow.compat.v1 as tf
import os 
import shutil
import csv
import pandas as pd
import IPython

tf.get_logger().setLevel('ERROR')

# %%
from tapas.utils import tf_example_utils
from tapas.protos import interaction_pb2
from tapas.utils import number_annotation_utils
from tapas.scripts import prediction_utils

# %%
os.makedirs('results/sqa/tf_examples', exist_ok=True)
os.makedirs('results/sqa/model', exist_ok=True)
with open('results/sqa/model/checkpoint', 'w') as f:
  f.write('model_checkpoint_path: "model.ckpt-0"')
for suffix in ['.data-00000-of-00001', '.index', '.meta']:
  shutil.copyfile(f'tapas_sqa_base/model.ckpt{suffix}', f'results/sqa/model/model.ckpt-0{suffix}')

# %%
data = data.astype(str)

# %%
data.head(10)
# Out:
#   Pos              Player          Team  ... HighestScore Average StrikeRate
# 0   1    Sachin Tendulkar         India  ...          200   44.83      86.23
# 1   2    Kumar Sangakkara     Sri Lanka  ...          169   41.98      78.86
# 2   3       Ricky Ponting     Australia  ...          164   42.03      80.39
# 3   4   Sanath Jayasuriya     Sri Lanka  ...          189   32.36       91.2
# 4   5  Mahela Jayawardene     Sri Lanka  ...          144   33.37      78.96
# 5   6         Virat Kohli         India  ...          183   59.85      93.39
# 6   7      Inzamam-ul-Haq      Pakistan  ...          137   39.52      74.24
# 7   8      Jacques Kallis  South Africa  ...          139   44.36      72.89
# 8   9      Saurav Ganguly         India  ...          183   41.02       73.7
# 9  10        Rahul Dravid         India  ...          153   39.16      71.24
#
# [10 rows x 9 columns]

# %%
list_of_list = [[]]
list_of_list[0] = list(data.columns)
list_of_list.extend(data.values.tolist())

# %%
list_of_list
# Out:
# [['Pos',
#   'Player',
#   'Team',
#   'Span',
#   'Innings',
#   'Runs',
#   'HighestScore',
#   'Average',
#   'StrikeRate'],
#  ['1',
#   'Sachin Tendulkar',
#   'India',
#   '1989-2012',
#   '452',
#   '18426',
#   '200',
#   '44.83',
#   '86.23'],
#  ['2',
#   'Kumar Sangakkara',
#   'Sri Lanka',
#   '2000-2015',
#   '380',
#   '14234',
#   '169',
#   '41.98',
#   '78.86'],
#  ['3',
#   'Ricky Ponting',
#   'Australia',
#   '1995-2012',
#   '365',
#   '13704',
#   '164',
#   '42.03',
#   '80.39'],
#  ['4',
#   'Sanath Jayasuriya',
#   'Sri Lanka',
#   '1989-2011',
#   '433',
#   '13430',
#   '189',
#   '32.36',
#   '91.2'],
#  ['5',
#   'Mahela Jayawardene',
#   'Sri Lanka',
#   '1998-2015',
#   '418',
#   '12650',
#   '144',
#   '33.37',
#   '78.96'],
#  ['6',
#   'Virat Kohli',
#   'India',
#   '2008-2020',
#   '236',
#   '11867',
#   '183',
#   '59.85',
#   '93.39'],
#  ['7',
#   'Inzamam-ul-Haq',
#   'Pakistan',
#   '1991-2007',
#   '350',
#   '11739',
#   '137',
# ...

# %%
max_seq_length = 512
vocab_file = "tapas_sqa_base/vocab.txt"
config = tf_example_utils.ClassifierConversionConfig(
    vocab_file=vocab_file,
    max_seq_length=max_seq_length,
    max_column_id=max_seq_length,
    max_row_id=max_seq_length,
    strip_column_names=False,
    add_aggregation_candidates=False,
)
converter = tf_example_utils.ToClassifierTensorflowExample(config)

def convert_interactions_to_examples(tables_and_queries):
  """Calls Tapas converter to convert interaction to example."""
  for idx, (table, queries) in enumerate(tables_and_queries):
    interaction = interaction_pb2.Interaction()
    for position, query in enumerate(queries):
      question = interaction.questions.add()
      question.original_text = query
      question.id = f"{idx}-0_{position}"
    for header in table[0]:
      interaction.table.columns.add().text = header
    for line in table[1:]:
      row = interaction.table.rows.add()
      for cell in line:
        row.cells.add().text = cell
    number_annotation_utils.add_numeric_values(interaction)
    for i in range(len(interaction.questions)):
      try:
        yield converter.convert(interaction, i)
      except ValueError as e:
        print(f"Can't convert interaction: {interaction.id} error: {e}")
        
def write_tf_example(filename, examples):
  with tf.io.TFRecordWriter(filename) as writer:
    for example in examples:
      writer.write(example.SerializeToString())

def predict(table_data, queries):
  table = table_data
  examples = convert_interactions_to_examples([(table, queries)])
  write_tf_example("results/sqa/tf_examples/test.tfrecord", examples)
  write_tf_example("results/sqa/tf_examples/random-split-1-dev.tfrecord", [])
  
  ! python tapas/tapas/run_task_main.py \
    --task="SQA" \
    --output_dir="results" \
    --noloop_predict \
    --test_batch_size={len(queries)} \
    --tapas_verbosity="ERROR" \
    --compression_type= \
    --init_checkpoint="tapas_sqa_base/model.ckpt" \
    --bert_config_file="tapas_sqa_base/bert_config.json" \
    --mode="predict" 2> error


  results_path = "results/sqa/model/test_sequence.tsv"
  all_coordinates = []
  df = pd.DataFrame(table[1:], columns=table[0])
  display(IPython.display.HTML(df.to_html(index=False)))
  print()
  with open(results_path) as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t')
    for row in reader:
      coordinates = prediction_utils.parse_coordinates(row["answer_coordinates"])
      all_coordinates.append(coordinates)
      answers = ', '.join([table[row + 1][col] for row, col in coordinates])
      position = int(row['position'])
      print(">", queries[position])
      print(answers)
  return all_coordinates

# %%
result = predict(list_of_list, ["what were the players names?",
      "of these, which team did Sachin Tendulkar play for?",
      "what is his highest score?",
      "how many runs has Virat Kohli scored?"])
# Out:
# is_built_with_cuda: True
# is_gpu_available: False
# GPUs: []
# Training or predicting ...
# Evaluation finished after training step 0.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Pos</th>
#       <th>Player</th>
#       <th>Team</th>
#       <th>Span</th>
#       <th>Innings</th>
#       <th>Runs</th>
#       <th>HighestScore</th>
#       <th>Average</th>
#       <th>StrikeRate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Sachin Tendulkar</td>
#       <td>India</td>
#       <td>1989-2012</td>
#       <td>452</td>
#       <td>18426</td>
#       <td>200</td>
#       <td>44.83</td>
#       <td>86.23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Kumar Sangakkara</td>
#       <td>Sri Lanka</td>
#       <td>2000-2015</td>
#       <td>380</td>
#       <td>14234</td>
#       <td>169</td>
#       <td>41.98</td>
#       <td>78.86</td>
#     </tr>
#     <tr>
#       <td>3</td>
# ...
